# %% [markdown]
# ## 1. Scrape the details of most viewed videos on YouTube from Wikipedia.
#
# Solution- This question I have done at the very end(after completion of the 10th question)

# %% [markdown]
# ### 2. Scrape the details team India’s international fixtures from bcci.tv.
# Url = https://www.bcci.tv/.
#
# You need to find following details:
#
# A) Match title (I.e. 1st ODI)
#
# B) Series
#
# C) Place
#
# D) Date
#
# E) Time
#
# Note: - From bcci.tv home page you have reach to the international fixture page through code

# %%
import pandas as pd
import selenium 
from selenium import webdriver
import warnings
warnings.filterwarnings('ignore')

# %%
driver=webdriver.Chrome(r"D:\chromedriver.exe")

# %%
driver.get('https://www.bcci.tv/.')

# %%
search_click=driver.find_element_by_xpath('/html/body/nav/div[1]/button/span[1]')
search_click.click()

# %%
search_click2=driver.find_element_by_xpath("/html/body/nav/div[1]/div[2]/ul[1]/li[2]/a")
search_click2.click()

# %%
Match_title=[]
Series=[]
Place=[]
Date=[]
Time=[]

# %%
ma=driver.find_elements_by_xpath("//span[@class='ng-binding']")
for i in ma:
    ma=i.text
    Match_title.append(ma)

# %%
se=driver.find_elements_by_xpath("//span[@class='matchOrderText ng-binding ng-scope']")
for i in se:
    se=i.text
    Series.append(se)

# %%
Pl=driver.find_elements_by_xpath("//span[@class='ng-binding ng-scope']")
for i in Pl:
    Pl=i.text
    Place.append(Pl)

# %%
Da=driver.find_elements_by_xpath("//div[@class='match-card-left match-schedule']")
for i in Da:
    Da=i.text
    Date.append(Da)

# %%
ta=driver.find_elements_by_xpath("//div[@class='match-card-right match-schedule ']")
for i in ta:
    ta=i.text
    Time.append(ta)

# %%
Final=pd.DataFrame({'Match title':Match_title,'Series':Series,'Place':Place,'Date':Date,'Time':Time})

# %%
Final
# Out:
#                                      Match title      Series  \
# 0  INDIA WOMEN TOUR OF SRI LANKA T20 SERIES 2022  1st T20I -
# 1  INDIA WOMEN TOUR OF SRI LANKA T20 SERIES 2022  2nd T20I -
# 2          INDIA TOUR OF IRELAND T20 SERIES 2022  1st T20I -
# 3  INDIA WOMEN TOUR OF SRI LANKA T20 SERIES 2022  3rd T20I -
# 4          INDIA TOUR OF IRELAND T20 SERIES 2022  2nd T20I -
# 5  INDIA WOMEN TOUR OF SRI LANKA ODI SERIES 2022   1st ODI -
# 6         INDIA TOUR OF ENGLAND TEST SERIES 2021  5th Test -
# 7  INDIA WOMEN TOUR OF SRI LANKA ODI SERIES 2022   2nd ODI -
# 8  INDIA WOMEN TOUR OF SRI LANKA ODI SERIES 2022   3rd ODI -
#
#                                       Place         Date          Time
# 0   Rangiri Dambulla International Stadium,  23 JUN 2022   2:30 PM IST
# 1   Rangiri Dambulla International Stadium,  25 JUN 2022   2:30 PM IST
# 2                              The Village,  26 JUN 2022   9:00 PM IST
# 3   Rangiri Dambulla International Stadium,  27 JUN 2022   2:30 PM IST
# ...

# %% [markdown]
# ### 3. Scrape the details of selenium exception from guru99.com.
# Url = https://www.guru99.com/
#
# You need to find following details:
#
# A) Name
#
# B) Description
#
# Note: - From guru99 home page you have to reach to selenium exception handling page through code.

# %%
driver=webdriver.Chrome(r'D:\chromedriver.exe')

# %%
driver.get("https://www.guru99.com/")

# %%
search=driver.find_element_by_xpath("/html/body/div[1]/header/div[1]/div/div/div/div/div/div/div/div[2]/div[2]/div/button/span")
search.click()

# %%
search2=driver.find_element_by_xpath("//input[@class='search-field']")
search2.send_keys("selenium exception handling")

# %%
search3=driver.find_element_by_xpath("/html/body/div[3]/div[2]/div[2]/form/input")
search3.click()

# %%
click=driver.find_element_by_xpath("/html/body/div[1]/div/div/div/main/div/article/div/div/div/div/div/div/div/div[5]/div[2]/div/div/div[1]/div[1]/div[1]/div[1]/div/a")
click.click()

# %%
Name_and_Description=[]

# %%
lop=[driver.find_elements_by_xpath("/html/body/div[1]/div/div/div/main/div/article/div/div/table/tbody/tr[2]"),
driver.find_elements_by_xpath("/html/body/div[1]/div/div/div/main/div/article/div/div/table/tbody/tr[3]"),
driver.find_elements_by_xpath("/html/body/div[1]/div/div/div/main/div/article/div/div/table/tbody/tr[4]"),
driver.find_elements_by_xpath("/html/body/div[1]/div/div/div/main/div/article/div/div/table/tbody/tr[5]"),
driver.find_elements_by_xpath("/html/body/div[1]/div/div/div/main/div/article/div/div/table/tbody/tr[6]"),
driver.find_elements_by_xpath("/html/body/div[1]/div/div/div/main/div/article/div/div/table/tbody/tr[7]"),
driver.find_elements_by_xpath("/html/body/div[1]/div/div/div/main/div/article/div/div/table/tbody/tr[8]"),
driver.find_elements_by_xpath("/html/body/div[1]/div/div/div/main/div/article/div/div/table/tbody/tr[9]"),
driver.find_elements_by_xpath("/html/body/div[1]/div/div/div/main/div/article/div/div/table/tbody/tr[10]"),
driver.find_elements_by_xpath("/html/body/div[1]/div/div/div/main/div/article/div/div/table/tbody/tr[11]"),
driver.find_elements_by_xpath("/html/body/div[1]/div/div/div/main/div/article/div/div/table/tbody/tr[12]"),
driver.find_elements_by_xpath("/html/body/div[1]/div/div/div/main/div/article/div/div/table/tbody/tr[13]"),
driver.find_elements_by_xpath("/html/body/div[1]/div/div/div/main/div/article/div/div/table/tbody/tr[14]"),
driver.find_elements_by_xpath("/html/body/div[1]/div/div/div/main/div/article/div/div/table/tbody/tr[15]"),
driver.find_elements_by_xpath("/html/body/div[1]/div/div/div/main/div/article/div/div/table/tbody/tr[16]"),
driver.find_elements_by_xpath("/html/body/div[1]/div/div/div/main/div/article/div/div/table/tbody/tr[17]"),
driver.find_elements_by_xpath("/html/body/div[1]/div/div/div/main/div/article/div/div/table/tbody/tr[18]"),
driver.find_elements_by_xpath("/html/body/div[1]/div/div/div/main/div/article/div/div/table/tbody/tr[19]"),
driver.find_elements_by_xpath("/html/body/div[1]/div/div/div/main/div/article/div/div/table/tbody/tr[20]"),
driver.find_elements_by_xpath("/html/body/div[1]/div/div/div/main/div/article/div/div/table/tbody/tr[21]"),
driver.find_elements_by_xpath("/html/body/div[1]/div/div/div/main/div/article/div/div/table/tbody/tr[22]"),
driver.find_elements_by_xpath("/html/body/div[1]/div/div/div/main/div/article/div/div/table/tbody/tr[23]"),
driver.find_elements_by_xpath("/html/body/div[1]/div/div/div/main/div/article/div/div/table/tbody/tr[24]"),
driver.find_elements_by_xpath("/html/body/div[1]/div/div/div/main/div/article/div/div/table/tbody/tr[25]"),
driver.find_elements_by_xpath("/html/body/div[1]/div/div/div/main/div/article/div/div/table/tbody/tr[26]"),
driver.find_elements_by_xpath("/html/body/div[1]/div/div/div/main/div/article/div/div/table/tbody/tr[27]"),
driver.find_elements_by_xpath("/html/body/div[1]/div/div/div/main/div/article/div/div/table/tbody/tr[28]"),
driver.find_elements_by_xpath("/html/body/div[1]/div/div/div/main/div/article/div/div/table/tbody/tr[29]"),
driver.find_elements_by_xpath("/html/body/div[1]/div/div/div/main/div/article/div/div/table/tbody/tr[30]"),
driver.find_elements_by_xpath("/html/body/div[1]/div/div/div/main/div/article/div/div/table/tbody/tr[31]"),
driver.find_elements_by_xpath("/html/body/div[1]/div/div/div/main/div/article/div/div/table/tbody/tr[32]"),
driver.find_elements_by_xpath("/html/body/div[1]/div/div/div/main/div/article/div/div/table/tbody/tr[33]"),
driver.find_elements_by_xpath("/html/body/div[1]/div/div/div/main/div/article/div/div/table/tbody/tr[34]"),
driver.find_elements_by_xpath("/html/body/div[1]/div/div/div/main/div/article/div/div/table/tbody/tr[35]"),
driver.find_elements_by_xpath("/html/body/div[1]/div/div/div/main/div/article/div/div/table/tbody/tr[36]"),
driver.find_elements_by_xpath("/html/body/div[1]/div/div/div/main/div/article/div/div/table/tbody/tr[37]"),
driver.find_elements_by_xpath("/html/body/div[1]/div/div/div/main/div/article/div/div/table/tbody/tr[38]"),
driver.find_elements_by_xpath("/html/body/div[1]/div/div/div/main/div/article/div/div/table/tbody/tr[39]"),
driver.find_elements_by_xpath("/html/body/div[1]/div/div/div/main/div/article/div/div/table/tbody/tr[40]"),
driver.find_elements_by_xpath("/html/body/div[1]/div/div/div/main/div/article/div/div/table/tbody/tr[41]"),
driver.find_elements_by_xpath("/html/body/div[1]/div/div/div/main/div/article/div/div/table/tbody/tr[42]")]

# %%
for i in lop:
    tt=i
    for j in tt:
        tt=j.text
        Name_and_Description.append(tt)

# %%
Name_and_Description
# Out:
# ['ElementNotVisibleException This type of Selenium exception occurs when an existing element in DOM has a feature set as hidden.',
#  'ElementNotSelectableException This Selenium exception occurs when an element is presented in the DOM, but you can be able to select. Therefore, it is not possible to interact.',
#  'NoSuchElementException This Exception occurs if an element could not be found.',
#  'NoSuchFrameException This Exception occurs if the frame target to be switched to does not exist.',
#  'NoAlertPresentException This Exception occurs when you switch to no presented alert.',
#  'NoSuchWindowException This Exception occurs if the window target to be switch does not exist.',
#  'StaleElementReferenceException This Selenium exception occurs happens when the web element is detached from the current DOM.',
#  'SessionNotFoundException The WebDriver is acting after you quit the browser.',
# ...

# %% [markdown]
# ### 4. Scrape the details of State-wise GDP of India from statisticstime.com.
# Url = http://statisticstimes.com/
#
# You have to find following details:
#
# A) Rank
#
# B) State
#
# C) GSDP(18-19)
#
# D) GSDP(17-18)
#
# E) Share(2017)
#
# F) GDP($ billion)
#
# Note: - From statisticstimes home page you have to reach to economy page through code.

# %%
driver=webdriver.Chrome(r'D:\chromedriver.exe')

# %%
driver.get('http://statisticstimes.com/')

# %%
search=driver.find_element_by_xpath("/html/body/div[2]/div[1]/div[2]/div[2]/button")
search.click()

# %%
urls=[]
url_1=driver.find_elements_by_xpath("/html/body/div[2]/div[1]/div[2]/div[2]/div/a[3]")
for i in url_1:
    urls.append(i.get_attribute("href"))

# %%
urls
# Out:
# ['https://www.statisticstimes.com/economy/india-statistics.php']

# %%
URL=[]
for i in urls:
    driver.get(i)
    
    aa=driver.find_elements_by_xpath("/html/body/div[2]/div[2]/div[2]/ul/li[1]/a")
    for x in aa:
        URL.append(x.get_attribute("href"))

# %%
URL
# Out:
# ['https://www.statisticstimes.com/economy/india/indian-states-gdp.php']

# %%
Rank=[]
for i in URL:
    driver.get(i)
    
    ra=driver.find_elements_by_xpath("//td[@class='data1']")
    for x in ra:
        ra=x.text
        Rank.append(ra)

# %%
Rank=Rank[0:33]

# %%
State=[]
for i in URL:
    driver.get(i)
    
    st=driver.find_elements_by_xpath("//td[@class='name']")
    for x in st:
        st=x.text
        State.append(st)

# %%
State=State[0:33]

# %%
Details=[]
for i in URL:
    driver.get(i)
    
    gs=driver.find_elements_by_xpath("//td[@class='data']")
    for x in gs:
        gs=x.text
        Details.append(gs)

# %%
GSDP_1=Details[0::5]

# %%
GSDP_1=GSDP_1[0:33]

# %%
Share=Details[1::5]

# %%
Share=Share[0:33]

# %%
GDP=Details[2::5]

# %%
GDP=GDP[0:33]

# %%
GSDP_2=[]
for i in URL:
    driver.get(i)
    
    gsd=driver.find_elements_by_xpath("//td[@class='data sorting_1']")
    for x in gsd:
        gsd=x.text
        GSDP_2.append(gsd)

# %%
GSDP_2=GSDP_2[0:33]

# %%
data=pd.DataFrame({'Rank':Rank,'State':State,'GSDP(18-19)':GSDP_2,"GSDP(19-20)":GSDP_1,'Share_2019':Share,'GDP($ billion)':GDP})

# %%
data
# Out:
#    Rank                      State GSDP(18-19) GSDP(19-20) Share_2019  \
# 0     1                Maharashtra   2,632,792           -     13.94%
# 1     2                 Tamil Nadu   1,630,208   1,845,853      8.63%
# 2     3              Uttar Pradesh   1,584,764   1,687,818      8.39%
# 3     4                    Gujarat   1,502,899           -      7.96%
# 4     5                  Karnataka   1,493,127   1,631,977      7.91%
# 5     6                West Bengal   1,089,898   1,253,832      5.77%
# 6     7                  Rajasthan     942,586   1,020,989      4.99%
# 7     8             Andhra Pradesh     862,957     972,782      4.57%
# 8     9                  Telangana     861,031     969,604      4.56%
# 9    10             Madhya Pradesh     809,592     906,672      4.29%
# 10   11                     Kerala     781,653           -      4.14%
# 11   12                      Delhi     774,870     856,112      4.10%
# ...

# %% [markdown]
# ### 5. Scrape the details of trending repositories on Github.com.
#
# Url = https://github.com/
#
# You have to find the following details:
#
# A) Repository title
#
# B) Repository description
#
# C) Contributors count
#
# D) Language used
#
# Note: - From the home page you have to click on the trending option from Explore menu through code.

# %%
driver=webdriver.Chrome(r"D:\chromedriver.exe")

# %%
driver.get("https://github.com/")

# %%
search=driver.find_element_by_xpath("/html/body/div[1]/header/div/div[2]/nav/ul/li[4]/details/summary")
search.click()

# %%
search2=driver.find_element_by_xpath("/html/body/div[1]/header/div/div[2]/nav/ul/li[4]/details/div/ul/li[5]/a")
search2.click()

# %%
urls=[]
url=driver.find_elements_by_xpath("/html/body/div[1]/header/div/div[2]/nav/ul/li[4]/details/div/ul/li[5]/a")
for i in url:
    urls.append(i.get_attribute("href"))

# %%
page_url=[]
for i in urls:
    driver.get(i)
    
    p1=driver.find_elements_by_xpath("/html/body/div[4]/main/div[3]/div/div[2]/article[1]/h1/a")
    p2=driver.find_elements_by_xpath("/html/body/div[4]/main/div[3]/div/div[2]/article[2]/h1/a")
    p3=driver.find_elements_by_xpath("/html/body/div[4]/main/div[3]/div/div[2]/article[3]/h1/a")
    p4=driver.find_elements_by_xpath("/html/body/div[4]/main/div[3]/div/div[2]/article[4]/h1/a")
    p5=driver.find_elements_by_xpath("/html/body/div[4]/main/div[3]/div/div[2]/article[5]/h1/a")
    p6=driver.find_elements_by_xpath("/html/body/div[4]/main/div[3]/div/div[2]/article[6]/h1/a")
    p7=driver.find_elements_by_xpath("/html/body/div[4]/main/div[3]/div/div[2]/article[7]/h1/a")
    p8=driver.find_elements_by_xpath("/html/body/div[4]/main/div[3]/div/div[2]/article[8]/h1/a")
    p9=driver.find_elements_by_xpath("/html/body/div[4]/main/div[3]/div/div[2]/article[9]/h1/a")
    p10=driver.find_elements_by_xpath("/html/body/div[4]/main/div[3]/div/div[2]/article[10]/h1/a")
    p11=driver.find_elements_by_xpath("/html/body/div[4]/main/div[3]/div/div[2]/article[11]/h1/a")
    p12=driver.find_elements_by_xpath("/html/body/div[4]/main/div[3]/div/div[2]/article[12]/h1/a")
    p13=driver.find_elements_by_xpath("/html/body/div[4]/main/div[3]/div/div[2]/article[13]/h1/a")
    p14=driver.find_elements_by_xpath("/html/body/div[4]/main/div[3]/div/div[2]/article[14]/h1/a")
    p15=driver.find_elements_by_xpath("/html/body/div[4]/main/div[3]/div/div[2]/article[15]/h1/a")
    p16=driver.find_elements_by_xpath("/html/body/div[4]/main/div[3]/div/div[2]/article[16]/h1/a")
    p17=driver.find_elements_by_xpath("/html/body/div[4]/main/div[3]/div/div[2]/article[17]/h1/a")
    p18=driver.find_elements_by_xpath("/html/body/div[4]/main/div[3]/div/div[2]/article[18]/h1/a")
    p19=driver.find_elements_by_xpath("/html/body/div[4]/main/div[3]/div/div[2]/article[19]/h1/a")
    p20=driver.find_elements_by_xpath("/html/body/div[4]/main/div[3]/div/div[2]/article[20]/h1/a")
    p21=driver.find_elements_by_xpath("/html/body/div[4]/main/div[3]/div/div[2]/article[21]/h1/a")
    p22=driver.find_elements_by_xpath("/html/body/div[4]/main/div[3]/div/div[2]/article[22]/h1/a")
    p23=driver.find_elements_by_xpath("/html/body/div[4]/main/div[3]/div/div[2]/article[23]/h1/a")
    p24=driver.find_elements_by_xpath("/html/body/div[4]/main/div[3]/div/div[2]/article[24]/h1/a")
    p25=driver.find_elements_by_xpath("/html/body/div[4]/main/div[3]/div/div[2]/article[25]/h1/a")
    
    for x in p1:
        page_url.append(x.get_attribute("href"))  
    for x in p2:
        page_url.append(x.get_attribute("href"))    
    for x in p3:
        page_url.append(x.get_attribute("href"))    
    for x in p4:
        page_url.append(x.get_attribute("href"))    
    for x in p5:
        page_url.append(x.get_attribute("href"))    
    for x in p6:
        page_url.append(x.get_attribute("href"))    
    for x in p7:
        page_url.append(x.get_attribute("href"))    
    for x in p8:
        page_url.append(x.get_attribute("href"))    
    for x in p9:
        page_url.append(x.get_attribute("href"))    
    for x in p10:
        page_url.append(x.get_attribute("href"))    
    for x in p11:
        page_url.append(x.get_attribute("href"))    
    for x in p12:
        page_url.append(x.get_attribute("href"))    
    for x in p13:
        page_url.append(x.get_attribute("href"))    
    for x in p14:
        page_url.append(x.get_attribute("href"))    
    for x in p15:
        page_url.append(x.get_attribute("href"))    
    for x in p16:
        page_url.append(x.get_attribute("href"))    
    for x in p17:
        page_url.append(x.get_attribute("href"))    
    for x in p18:
        page_url.append(x.get_attribute("href"))    
    for x in p19:
        page_url.append(x.get_attribute("href"))    
    for x in p20:
        page_url.append(x.get_attribute("href"))    
    for x in p21:
        page_url.append(x.get_attribute("href"))    
    for x in p22:
        page_url.append(x.get_attribute("href"))    
    for x in p23:
        page_url.append(x.get_attribute("href"))    
    for x in p24:
        page_url.append(x.get_attribute("href"))    
    for x in p25:
        page_url.append(x.get_attribute("href"))

# %%
Repository_title=[]
for i in page_url:
    driver.get(i)
    
    rt=driver.find_elements_by_xpath("//span[@class='author flex-self-stretch']")
    for x in rt:
        rt=x.text
        Repository_title.append(rt)

# %%
Repository_description=[]
for i in page_url:
    driver.get(i)
    
    try:
        rd=driver.find_element_by_xpath("//p[@class='f4 my-3']")
        Repository_description.append(rd.text)
        
    except NoSuchElementException:
        Repository_description.append("---")

# %%
from selenium.common.exceptions import NoSuchElementException, StaleElementReferenceException,InvalidArgumentException,WebDriverException

# %%
anguage_used=[]
for i in page_url:
    driver.get(i)
    
    try:
        ls=driver.find_element_by_xpath("//li[@class='d-inline']")
        anguage_used.append(ls.text)
    except NoSuchElementException :
        anguage_used.append("---")

# %%
Contributors_count=[]
for i in page_url:
    driver.get(i)
    
    try:
        cc=driver.find_element_by_xpath("//span[@class='Counter']")
        Contributors_count.append(cc.text)
    except NoSuchElementException :
        Contributors_count.append("---")

# %%
data=pd.DataFrame({'Repository_title':Repository_title,'Repository_description':Repository_description,'Language_used':anguage_used,
                  'Contributors_count':Contributors_count})

# %%
data
# Out:
#          Repository_title                             Repository_description  \
# 0              mingrammer  🎨 Diagram as Code for prototyping cloud system...
# 1               hashicorp  Nomad is an easy-to-use, flexible, and perform...
# 2                facebook  Lexical is an extensible text editor framework...
# 3               girliemac  I am trying to describe complex matters in sim...
# 4                WenchaoD  A fully customizable iOS calendar library, com...
# 5               PrefectHQ              The easiest way to automate your data
# 6               Reiten966  Polyformer is an open-source project that aims...
# 7               hashicorp       HCL is the HashiCorp configuration language.
# 8                 pittcsc        Collection of Summer 2023 tech internships!
# 9                Technawi                                                ---
# 10                 apache                                       Apache HBase
# ...

# %% [markdown]
# ### 6. Scrape the details of top 100 songs on billiboard.com.
#
# Url = https:/www.billboard.com/
#
# You have to find the following details:
#
# A) Song name
#
# B) Artist name
#
# C) Last week rank
#
# D) Peak rank
#
# E) Weeks on board
#
# Note: - From the home page you have to click on the charts option then hot 100-page link through code.

# %%
driver=webdriver.Chrome(r'D:\chromedriver.exe')

# %%
driver.get("https:/www.billboard.com/")

# %%
search=driver.find_element_by_xpath("/html/body/div[3]/div[6]/div/div/div/ul/li[1]/h3/a")
search.click()

# %%
urll=[]
hot=driver.find_elements_by_xpath("/html/body/div[3]/main/div[2]/div[1]/div[1]/div/div/div[1]/div[1]/div[2]/span/a")
for i in hot:
    urll.append(i.get_attribute("href"))

# %%
Song_name=[]
for i in urll:
    driver.get(i)
    
    sn=driver.find_elements_by_xpath("//h3[@class='c-title  a-no-trucate a-font-primary-bold-s u-letter-spacing-0021 lrv-u-font-size-18@tablet lrv-u-font-size-16 u-line-height-125 u-line-height-normal@mobile-max a-truncate-ellipsis u-max-width-330 u-max-width-230@tablet-only']")
    for i in sn:
        sn=i.text
        Song_name.append(sn)

# %%
Artist_name=[]
for i in urll:
    driver.get(i)
    
    an=driver.find_elements_by_xpath("//span[@class='c-label  a-no-trucate a-font-primary-s lrv-u-font-size-14@mobile-max u-line-height-normal@mobile-max u-letter-spacing-0021 lrv-u-display-block a-truncate-ellipsis-2line u-max-width-330 u-max-width-230@tablet-only']")
    for i in an:
        an=i.text
        Artist_name.append(an)

# %%
rank=[]
for i in urll:
    driver.get(i)
    
    an=driver.find_elements_by_xpath("//li[@class='o-chart-results-list__item // a-chart-color u-width-72 u-width-55@mobile-max u-width-55@tablet-only lrv-u-flex lrv-u-flex-shrink-0 lrv-u-align-items-center lrv-u-justify-content-center lrv-u-border-b-1 u-border-b-0@mobile-max lrv-u-border-color-grey-light u-background-color-white-064@mobile-max u-hidden@mobile-max']")
    for i in an:
        an=i.text
        rank.append(an)

# %%
Last_week_rank=rank[0::2]

# %%
Weeks_on_board=rank[1::2]

# %%
pr=[]
for i in urll:
    driver.get(i)
    
    an=driver.find_elements_by_xpath("//li[@class='o-chart-results-list__item // a-chart-bg-color a-chart-color u-width-72 u-width-55@mobile-max u-width-55@tablet-only lrv-u-flex lrv-u-flex-shrink-0 lrv-u-align-items-center lrv-u-justify-content-center lrv-u-background-color-grey-lightest lrv-u-border-b-1 u-border-b-0@mobile-max lrv-u-border-color-grey-light u-hidden@mobile-max']")
    for i in an:
        an=i.text
        pr.append(an)

# %%
Peak_rank=pr[1::2]

# %%
data=pd.DataFrame({'Song name':Song_name,'Artist name':Artist_name,'Last week rank':Last_week_rank,
                  'Peak rank':Peak_rank,'Weeks on board':Weeks_on_board})

# %%
data
# Out:
#                                  Song name  \
# 0                                As it was
# 1                              First Class
# 2                               Wait For U
# 3                          About Damn Time
# 4   Running Up That Hill (A Deal With God)
# ..                                     ...
# 95                                  Plan B
# 96                             Tomorrow Me
# 97                                  Potion
# 98                               New Truck
# 99              Wrapped Around Your Finger
#
#                              Artist name Last week rank Peak rank  \
# 0                           Harry Styles              1         1
# 1                            Jack Harlow              2         1
# 2          Future Featuring Drake & Tems              3         1
# 3                                  Lizzo              5         4
# 4                              Kate Bush              4         4
# ...

# %% [markdown]
# ### 7. Scrape the details of Data science recruiters from naukri.com.
#
# Url = https://www.naukri.com/
#
# You have to find the following details:
#
# A) Name
#
# B) Designation
#
# C) Company
#
# D) Skills they hire for
#
# E) Location
#
# Note: - From naukri.com homepage click on the recruiters option and the on the search pane type Data science and
# click on search. All this should be done through code

# %%
driver=webdriver.Chrome(r'D:\chromedriver.exe')

# %%
driver.get("https://www.naukri.com/")

# %%
search2=driver.find_element_by_xpath("//input[@class='suggestor-input ']")
search2.send_keys("Data science")

# %%
search3=driver.find_element_by_xpath("/html/body/div/div[2]/div[3]/div/div/div[6]")
search3.click()

# %%
urls=[]
url=driver.find_elements_by_xpath("//a[@class='title fw500 ellipsis']")
for i in url:
    urls.append(i.get_attribute("href"))

# %%
Name=[]
for i in urls:
    driver.get(i)
    
    try:
        na=driver.find_element_by_xpath("//h1[@class='jd-header-title']")
        Name.append(na.text)
    except NoSuchElementException:
        Name.append("---")

# %%
Designation=[]
for i in urls:
    driver.get(i)
    
    try:
        na=driver.find_element_by_xpath("/html/body/div[1]/main/div[2]/div[2]/section[2]/div[2]/div[1]")
        Designation.append(na.text)
    except NoSuchElementException:
        Designation.append("---")

# %%
dd=[]
for i in Designation:
    
    dd.append(i[4:])

# %%
Company=[]
for i in urls:
    driver.get(i)
    
    try:
        na=driver.find_element_by_xpath("/html/body/div[1]/main/div[2]/div[2]/section[1]/div[1]/div[1]/div/a[1]")
        Company.append(na.text)
    except NoSuchElementException:
        Company.append("---")

# %%
Skills=[]
for i in urls:
    driver.get(i)
    
    try:
        na=driver.find_element_by_xpath("/html/body/div[1]/main/div[2]/div[2]/section[2]/div[4]")
        Skills.append(na.text)
    except NoSuchElementException:
        Skills.append("---")

# %%
SS=[]
for i in Skills:
    SS.append(i[11:])

# %%
Location=[]
for i in urls:
    driver.get(i)
    
    try:
        na=driver.find_element_by_xpath("/html/body/div[1]/main/div[2]/div[2]/section[1]/div[1]/div[2]/div[3]/span")
        Location.append(na.text)
    except NoSuchElementException:
        Location.append("---")

# %%
data=pd.DataFrame({'Company':Company,'Name':Name,'Designation':dd,'Skills':SS,'Location':Location})

# %%
data
# Out:
#                                Company  \
# 0   Naukri Premium - Employer Services
# 1                            Accenture
# 2                    Fractal Analytics
# 3                                Shell
# 4      Rise Finconnect Private Limited
# 5                                Paytm
# 6                            Accenture
# 7         Ecom Express Private Limited
# 8                            Accenture
# 9                     HCL Technologies
# 10                           Accenture
# 11                           Accenture
# 12                             Coforge
# 13                                PayU
# 14                   Dell Technologies
# 15           Allstate Solutions (ASPL)
# 16                             Walmart
# 17        Ecom Express Private Limited
# 18        Ecom Express Private Limited
#
#                                                  Name  \
# 0                        Data Analysis / Data Science
# 1       India Market Unit - Data Science Analyst - 11
# ...

# %% [markdown]
# ### 8. Scrape the details of Highest selling novels.
#
# Url = https://www.theguardian.com/news/datablog/2012/aug/09/best-selling-books-all-time-fifty-shades-grey-compare
#
# You have to find the following details:
#
# A) Book name
#
# B) Author name
#
# C) Volumes sold
#
# D) Publisher
#
# E) Genre

# %%
driver=webdriver.Chrome(r'D:\chromedriver.exe')

# %%
driver.get("https://www.theguardian.com/news/datablog/2012/aug/09/best-selling-books-all-time-fifty-shades-grey-compare")

# %%
Details=[]
bn=driver.find_elements_by_xpath("//td[@class='left']")
for i in bn:
    bn=i.text
    Details.append(bn)

# %%
Rank=Details[0::5]
Book_name=Details[1::5]
Author_name=Details[2::5]
Volumes_sold=Details[3::5]
Publisher=Details[4::5]

# %%
Genre=[]
bn=driver.find_elements_by_xpath("//td[@class='last left']")
for i in bn:
    bn=i.text
    Genre.append(bn)

# %%
data=pd.DataFrame({"Rank":Rank,'Book Name':Book_name,'Author Name':Author_name,"Volume Sold":Volumes_sold,'Publisher':Publisher,'Genre':Genre})

# %%
data
# Out:
#    Rank                                          Book Name       Author Name  \
# 0     1                                  Da Vinci Code,The        Brown, Dan
# 1     2               Harry Potter and the Deathly Hallows     Rowling, J.K.
# 2     3           Harry Potter and the Philosopher's Stone     Rowling, J.K.
# 3     4          Harry Potter and the Order of the Phoenix     Rowling, J.K.
# 4     5                               Fifty Shades of Grey      James, E. L.
# ..  ...                                                ...               ...
# 95   96                                          Ghost,The    Harris, Robert
# 96   97                     Happy Days with the Naked Chef     Oliver, Jamie
# 97   98              Hunger Games,The:Hunger Games Trilogy  Collins, Suzanne
# 98   99  Lost Boy,The:A Foster Child's Search for the L...      Pelzer, Dave
# 99  100  Jamie's Ministry of Food:Anyone Can Learn to C...     Oliver, Jamie
#
# ...

# %% [markdown]
# ### 9. Scrape the details most watched tv series of all time from imdb.com.
#
# Url = https://www.imdb.com/list/ls095964455/
#
# You have to find the following details:
#
# A) Name
#
# B) Year span
#
# C) Genre
#
# D) Run time
#
# E) Rating

# %%
driver=webdriver.Chrome(r'D:\chromedriver.exe')

# %%
driver.get('https://www.imdb.com/list/ls095964455/')

# %%
Name=[]
na=driver.find_elements_by_xpath("//h3[@class='lister-item-header']")
for i in na:
    na=i.text
    Name.append(na)

# %%
name=[]
for i in Name:
    name.append(i[3:])

# %%
Year=[]
na=driver.find_elements_by_xpath("//span[@class='lister-item-year text-muted unbold']")
for i in na:
    na=i.text
    Year.append(na)

# %%
Genre=[]
na=driver.find_elements_by_xpath("//span[@class='genre']")
for i in na:
    na=i.text
    Genre.append(na)

# %%
Run_time=[]
na=driver.find_elements_by_xpath("//span[@class='runtime']")
for i in na:
    na=i.text
    Run_time.append(na)

# %%
Rating=[]
na=driver.find_elements_by_xpath("//div[@class='ipl-rating-star small']")
for i in na:
    na=i.text
    Rating.append(na)

# %%
data=pd.DataFrame({'Name':name,'Year':Year,'Genre':Genre,'Run time':Run_time,'Rating':Rating})

# %%
data
# Out:
#                                            Name         Year  \
# 0                   Game of Thrones (2011–2019)  (2011–2019)
# 1                      Stranger Things (2016– )     (2016– )
# 2                  The Walking Dead (2010–2022)  (2010–2022)
# 3                    13 Reasons Why (2017–2020)  (2017–2020)
# 4                           The 100 (2014–2020)  (2014–2020)
# ..                                          ...          ...
# 95                            Reign (2013–2017)  (2013–2017)
# 96   A Series of Unfortunate Events (2017–2019)  (2017–2019)
# 97                   Criminal Minds (2005–2020)  (2005–2020)
# 98            Scream: The TV Series (2015–2019)  (2015–2019)
# 99          . The Haunting of Hill House (2018)       (2018)
#
#                        Genre Run time Rating
# 0   Action, Adventure, Drama   57 min    9.2
# 1     Drama, Fantasy, Horror   51 min    8.7
# 2    Drama, Horror, Thriller   44 min    8.2
# 3   Drama, Mystery, Thriller   60 min    7.5
# ...

# %% [markdown]
# ### 10. Details of Datasets from UCI machine learning repositories.
#
# Url = https://archive.ics.uci.edu/
#
# You have to find the following details:
#
# A) Dataset name
#
# B) Data type
#
# C) Task
#
# D) Attribute type
#
# E) No of instances
#
# F) No of attribute
#
# G) Year
#
# Note: - from the home page you have to go to the ShowAllDataset page through code

# %%
driver=webdriver.Chrome(r'D:\chromedriver.exe')

# %%
driver.get('https://archive.ics.uci.edu/ml/index.php')

# %%
urls=[]
url=driver.find_elements_by_xpath("/html/body/table[1]/tbody/tr/td[2]/span[2]/a")
for i in url:
    urls.append(i.get_attribute("href"))

# %%
details=[]
dn=driver.find_elements_by_xpath("//p[@class='normal']")
for i in dn:
    dn=i.text
    details.append(dn)

# %%
Dataset_name=details[0::7]
Data_type=details[1::7]
Task=details[2::7]
Attribute_type=details[3::7]
No_of_instances=details[4::7]
No_of_attribute=details[5::7]
Year=details[6::7]

# %%
Dataset_name=Dataset_name[0:-1]

# %%
Data_type=Data_type[0:-1]

# %%
data=pd.DataFrame({'Dataset name':Dataset_name,'Data type':Data_type,'Task':Task,"Attribute type":Attribute_type,
                  "No of instances":No_of_instances,'No of attribute':No_of_attribute,'Year':Year})

# %%
data
# Out:
#                                           Dataset name  \
# 0                                              Abalone
# 1                                                Adult
# 2                                            Annealing
# 3                         Anonymous Microsoft Web Data
# 4                                           Arrhythmia
# ..                                                 ...
# 617  Influenza outbreak event prediction via Twitte...
# 618                      Turkish Music Emotion Dataset
# 619                      Maternal Health Risk Data Set
# 620                          Room Occupancy Estimation
# 621  Image Recognition Task Execution Times in Mobi...
#
#                       Data type                  Task  \
# 0                 Multivariate        Classification
# 1                 Multivariate        Classification
# 2                 Multivariate        Classification
# 3                                Recommender-Systems
# ...

# %% [markdown]
# ### 1. Scrape the details of most viewed videos on YouTube from Wikipedia.
#
# Url = https://en.wikipedia.org/wiki/List_of_most-viewed_YouTube_videos
#
# You need to find following details:
#
# A) Rank
#
# B) Name
#
# C) Artist
#
# D) Upload date
#
# E) Views

# %%
driver=webdriver.Chrome(r'D:\chromedriver.exe')

# %%
driver.get('https://en.wikipedia.org/wiki/List_of_most-viewed_YouTube_videos')

# %%
x_path=[driver.find_element_by_xpath("/html/body/div[3]/div[3]/div[5]/div[1]/table[2]/tbody/tr[1]/td[2]"),
driver.find_element_by_xpath("/html/body/div[3]/div[3]/div[5]/div[1]/table[2]/tbody/tr[2]/td[2]"),
driver.find_element_by_xpath("/html/body/div[3]/div[3]/div[5]/div[1]/table[2]/tbody/tr[3]/td[2]"),
driver.find_element_by_xpath("/html/body/div[3]/div[3]/div[5]/div[1]/table[2]/tbody/tr[4]/td[2]"),
driver.find_element_by_xpath("/html/body/div[3]/div[3]/div[5]/div[1]/table[2]/tbody/tr[5]/td[2]"),
driver.find_element_by_xpath("/html/body/div[3]/div[3]/div[5]/div[1]/table[2]/tbody/tr[6]/td[2]"),
driver.find_element_by_xpath("/html/body/div[3]/div[3]/div[5]/div[1]/table[2]/tbody/tr[7]/td[2]"),
driver.find_element_by_xpath("/html/body/div[3]/div[3]/div[5]/div[1]/table[2]/tbody/tr[8]/td[2]"),
driver.find_element_by_xpath("/html/body/div[3]/div[3]/div[5]/div[1]/table[2]/tbody/tr[9]/td[2]"),
driver.find_element_by_xpath("/html/body/div[3]/div[3]/div[5]/div[1]/table[2]/tbody/tr[10]/td[2]"),
driver.find_element_by_xpath("/html/body/div[3]/div[3]/div[5]/div[1]/table[2]/tbody/tr[11]/td[2]"),
driver.find_element_by_xpath("/html/body/div[3]/div[3]/div[5]/div[1]/table[2]/tbody/tr[12]/td[2]"),
driver.find_element_by_xpath("/html/body/div[3]/div[3]/div[5]/div[1]/table[2]/tbody/tr[13]/td[2]"),
driver.find_element_by_xpath("/html/body/div[3]/div[3]/div[5]/div[1]/table[2]/tbody/tr[14]/td[2]"),
driver.find_element_by_xpath("/html/body/div[3]/div[3]/div[5]/div[1]/table[2]/tbody/tr[15]/td[2]"),
driver.find_element_by_xpath("/html/body/div[3]/div[3]/div[5]/div[1]/table[2]/tbody/tr[16]/td[2]"),
driver.find_element_by_xpath("/html/body/div[3]/div[3]/div[5]/div[1]/table[2]/tbody/tr[17]/td[2]"),
driver.find_element_by_xpath("/html/body/div[3]/div[3]/div[5]/div[1]/table[2]/tbody/tr[18]/td[2]"),
driver.find_element_by_xpath("/html/body/div[3]/div[3]/div[5]/div[1]/table[2]/tbody/tr[19]/td[2]"),
driver.find_element_by_xpath("/html/body/div[3]/div[3]/div[5]/div[1]/table[2]/tbody/tr[20]/td[2]"),
driver.find_element_by_xpath("/html/body/div[3]/div[3]/div[5]/div[1]/table[2]/tbody/tr[21]/td[2]"),
driver.find_element_by_xpath("/html/body/div[3]/div[3]/div[5]/div[1]/table[2]/tbody/tr[22]/td[2]"),
driver.find_element_by_xpath("/html/body/div[3]/div[3]/div[5]/div[1]/table[2]/tbody/tr[23]/td[2]"),
driver.find_element_by_xpath("/html/body/div[3]/div[3]/div[5]/div[1]/table[2]/tbody/tr[24]/td[2]"),
driver.find_element_by_xpath("/html/body/div[3]/div[3]/div[5]/div[1]/table[2]/tbody/tr[25]/td[2]"),
driver.find_element_by_xpath("/html/body/div[3]/div[3]/div[5]/div[1]/table[2]/tbody/tr[26]/td[2]"),
driver.find_element_by_xpath("/html/body/div[3]/div[3]/div[5]/div[1]/table[2]/tbody/tr[27]/td[2]"),
driver.find_element_by_xpath("/html/body/div[3]/div[3]/div[5]/div[1]/table[2]/tbody/tr[28]/td[2]"),
driver.find_element_by_xpath("/html/body/div[3]/div[3]/div[5]/div[1]/table[2]/tbody/tr[29]/td[2]"),
driver.find_element_by_xpath("/html/body/div[3]/div[3]/div[5]/div[1]/table[2]/tbody/tr[30]/td[2]")]

# %%
Name=[]

for i in x_path:
    xp=i
    xp=i.text
    Name.append(xp)

# %%
xpath=[driver.find_element_by_xpath("/html/body/div[3]/div[3]/div[5]/div[1]/table[2]/tbody/tr[1]/td[3]"),
driver.find_element_by_xpath("/html/body/div[3]/div[3]/div[5]/div[1]/table[2]/tbody/tr[2]/td[3]"),
driver.find_element_by_xpath("/html/body/div[3]/div[3]/div[5]/div[1]/table[2]/tbody/tr[3]/td[3]"),
driver.find_element_by_xpath("/html/body/div[3]/div[3]/div[5]/div[1]/table[2]/tbody/tr[4]/td[3]"),
driver.find_element_by_xpath("/html/body/div[3]/div[3]/div[5]/div[1]/table[2]/tbody/tr[5]/td[3]"),
driver.find_element_by_xpath("/html/body/div[3]/div[3]/div[5]/div[1]/table[2]/tbody/tr[6]/td[3]"),
driver.find_element_by_xpath("/html/body/div[3]/div[3]/div[5]/div[1]/table[2]/tbody/tr[7]/td[3]"),
driver.find_element_by_xpath("/html/body/div[3]/div[3]/div[5]/div[1]/table[2]/tbody/tr[8]/td[3]"),
driver.find_element_by_xpath("/html/body/div[3]/div[3]/div[5]/div[1]/table[2]/tbody/tr[9]/td[3]"),
driver.find_element_by_xpath("/html/body/div[3]/div[3]/div[5]/div[1]/table[2]/tbody/tr[10]/td[3]"),
driver.find_element_by_xpath("/html/body/div[3]/div[3]/div[5]/div[1]/table[2]/tbody/tr[11]/td[3]"),
driver.find_element_by_xpath("/html/body/div[3]/div[3]/div[5]/div[1]/table[2]/tbody/tr[12]/td[3]"),
driver.find_element_by_xpath("/html/body/div[3]/div[3]/div[5]/div[1]/table[2]/tbody/tr[13]/td[3]"),
driver.find_element_by_xpath("/html/body/div[3]/div[3]/div[5]/div[1]/table[2]/tbody/tr[14]/td[3]"),
driver.find_element_by_xpath("/html/body/div[3]/div[3]/div[5]/div[1]/table[2]/tbody/tr[15]/td[3]"),
driver.find_element_by_xpath("/html/body/div[3]/div[3]/div[5]/div[1]/table[2]/tbody/tr[16]/td[3]"),
driver.find_element_by_xpath("/html/body/div[3]/div[3]/div[5]/div[1]/table[2]/tbody/tr[17]/td[3]"),
driver.find_element_by_xpath("/html/body/div[3]/div[3]/div[5]/div[1]/table[2]/tbody/tr[18]/td[3]"),
driver.find_element_by_xpath("/html/body/div[3]/div[3]/div[5]/div[1]/table[2]/tbody/tr[19]/td[3]"),
driver.find_element_by_xpath("/html/body/div[3]/div[3]/div[5]/div[1]/table[2]/tbody/tr[20]/td[3]"),
driver.find_element_by_xpath("/html/body/div[3]/div[3]/div[5]/div[1]/table[2]/tbody/tr[21]/td[3]"),
driver.find_element_by_xpath("/html/body/div[3]/div[3]/div[5]/div[1]/table[2]/tbody/tr[22]/td[3]"),
driver.find_element_by_xpath("/html/body/div[3]/div[3]/div[5]/div[1]/table[2]/tbody/tr[23]/td[3]"),
driver.find_element_by_xpath("/html/body/div[3]/div[3]/div[5]/div[1]/table[2]/tbody/tr[24]/td[3]"),
driver.find_element_by_xpath("/html/body/div[3]/div[3]/div[5]/div[1]/table[2]/tbody/tr[25]/td[3]"),
driver.find_element_by_xpath("/html/body/div[3]/div[3]/div[5]/div[1]/table[2]/tbody/tr[26]/td[3]"),
driver.find_element_by_xpath("/html/body/div[3]/div[3]/div[5]/div[1]/table[2]/tbody/tr[27]/td[3]"),
driver.find_element_by_xpath("/html/body/div[3]/div[3]/div[5]/div[1]/table[2]/tbody/tr[28]/td[3]"),
driver.find_element_by_xpath("/html/body/div[3]/div[3]/div[5]/div[1]/table[2]/tbody/tr[29]/td[3]"),
driver.find_element_by_xpath("/html/body/div[3]/div[3]/div[5]/div[1]/table[2]/tbody/tr[30]/td[3]")]

# %%
Artist=[]

for i in xpath:
    xp=i
    xp=i.text
    Artist.append(xp)

# %%
Rank=[]
for i in range(1,31):
    Rank.append(i)

# %%
Upload_date=[]
up=driver.find_elements_by_xpath("//td[@align='right']")
for i in up:
    up=i.text
    Upload_date.append(up)

# %%
xpath2=[driver.find_element_by_xpath("/html/body/div[3]/div[3]/div[5]/div[1]/table[2]/tbody/tr[1]/td[4]"),
driver.find_element_by_xpath("/html/body/div[3]/div[3]/div[5]/div[1]/table[2]/tbody/tr[2]/td[4]"),
driver.find_element_by_xpath("/html/body/div[3]/div[3]/div[5]/div[1]/table[2]/tbody/tr[3]/td[4]"),
driver.find_element_by_xpath("/html/body/div[3]/div[3]/div[5]/div[1]/table[2]/tbody/tr[4]/td[4]"),
driver.find_element_by_xpath("/html/body/div[3]/div[3]/div[5]/div[1]/table[2]/tbody/tr[5]/td[4]"),
driver.find_element_by_xpath("/html/body/div[3]/div[3]/div[5]/div[1]/table[2]/tbody/tr[6]/td[4]"),
driver.find_element_by_xpath("/html/body/div[3]/div[3]/div[5]/div[1]/table[2]/tbody/tr[7]/td[4]"),
driver.find_element_by_xpath("/html/body/div[3]/div[3]/div[5]/div[1]/table[2]/tbody/tr[8]/td[4]"),
driver.find_element_by_xpath("/html/body/div[3]/div[3]/div[5]/div[1]/table[2]/tbody/tr[9]/td[4]"),
driver.find_element_by_xpath("/html/body/div[3]/div[3]/div[5]/div[1]/table[2]/tbody/tr[10]/td[4]"),
driver.find_element_by_xpath("/html/body/div[3]/div[3]/div[5]/div[1]/table[2]/tbody/tr[11]/td[4]"),
driver.find_element_by_xpath("/html/body/div[3]/div[3]/div[5]/div[1]/table[2]/tbody/tr[12]/td[4]"),
driver.find_element_by_xpath("/html/body/div[3]/div[3]/div[5]/div[1]/table[2]/tbody/tr[13]/td[4]"),
driver.find_element_by_xpath("/html/body/div[3]/div[3]/div[5]/div[1]/table[2]/tbody/tr[14]/td[4]"),
driver.find_element_by_xpath("/html/body/div[3]/div[3]/div[5]/div[1]/table[2]/tbody/tr[15]/td[4]"),
driver.find_element_by_xpath("/html/body/div[3]/div[3]/div[5]/div[1]/table[2]/tbody/tr[16]/td[4]"),
driver.find_element_by_xpath("/html/body/div[3]/div[3]/div[5]/div[1]/table[2]/tbody/tr[17]/td[4]"),
driver.find_element_by_xpath("/html/body/div[3]/div[3]/div[5]/div[1]/table[2]/tbody/tr[18]/td[4]"),
driver.find_element_by_xpath("/html/body/div[3]/div[3]/div[5]/div[1]/table[2]/tbody/tr[19]/td[4]"),
driver.find_element_by_xpath("/html/body/div[3]/div[3]/div[5]/div[1]/table[2]/tbody/tr[20]/td[4]"),
driver.find_element_by_xpath("/html/body/div[3]/div[3]/div[5]/div[1]/table[2]/tbody/tr[21]/td[4]"),
driver.find_element_by_xpath("/html/body/div[3]/div[3]/div[5]/div[1]/table[2]/tbody/tr[22]/td[4]"),
driver.find_element_by_xpath("/html/body/div[3]/div[3]/div[5]/div[1]/table[2]/tbody/tr[23]/td[4]"),
driver.find_element_by_xpath("/html/body/div[3]/div[3]/div[5]/div[1]/table[2]/tbody/tr[24]/td[4]"),
driver.find_element_by_xpath("/html/body/div[3]/div[3]/div[5]/div[1]/table[2]/tbody/tr[25]/td[4]"),
driver.find_element_by_xpath("/html/body/div[3]/div[3]/div[5]/div[1]/table[2]/tbody/tr[26]/td[4]"),
driver.find_element_by_xpath("/html/body/div[3]/div[3]/div[5]/div[1]/table[2]/tbody/tr[27]/td[4]"),
driver.find_element_by_xpath("/html/body/div[3]/div[3]/div[5]/div[1]/table[2]/tbody/tr[28]/td[4]"),
driver.find_element_by_xpath("/html/body/div[3]/div[3]/div[5]/div[1]/table[2]/tbody/tr[29]/td[4]"),
driver.find_element_by_xpath("/html/body/div[3]/div[3]/div[5]/div[1]/table[2]/tbody/tr[30]/td[4]")]

# %%
Views=[]

for i in xpath2:
    xp=i
    xp=i.text
    Views.append(xp)

# %%
data=pd.DataFrame({'Rank':Rank,'Name':Name,'Artist':Artist,'Upload date':Upload_date,'Views':Views})

# %%
data
# Out:
#     Rank                                             Name  \
# 0      1                            "Baby Shark Dance"[3]
# 1      2                                   "Despacito"[6]
# 2      3                       "Johny Johny Yes Papa"[12]
# 3      4                               "Shape of You"[13]
# 4      5                              "See You Again"[15]
# 5      6                                  "Bath Song"[20]
# 6      7                "Phonics Song with Two Words"[21]
# 7      8                                "Uptown Funk"[22]
# 8      9  "Learning Colors – Colorful Eggs on a Farm"[23]
# 9     10   "Masha and the Bear – Recipe for Disaster"[24]
# 10    11                              "Gangnam Style"[25]
# 11    12                          "Wheels on the Bus"[30]
# 12    13                             "Dame Tu Cosita"[31]
# 13    14                                      "Sugar"[32]
# 14    15                                       "Roar"[33]
# ...

# %% [markdown]
# ## ---------------------------------------------------------------------------------------------------------------------------------
