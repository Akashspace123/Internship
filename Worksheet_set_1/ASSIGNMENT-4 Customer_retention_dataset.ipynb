# %% [markdown]
# ### Customer retention

# %% [markdown]
# The best customers are the ones who keep coming back to you for more, who choose you over competitors. They always boost your earnings. And therefore, customer retention plays a significant role in the management of a successful business.
#
# Customer retention refers to the ability of a company or product to retain its customers over some specified period.High customer retention means customers of the product or business tend to return to, continue to buy or in some other way not defect to another product or business, or to non-use entirely.
#
# Don’t you want to build meaningful, long-term and revenue-generating relationships with your customers? Then applying customer retention strategies will take your business a long way.

# %% [markdown]
# .

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %%
data=pd.read_excel(r"C:\Users\ABC\OneDrive\Desktop\customer_retention_dataset.xlsx")
data.head()
# Out:
#   1Gender of respondent 2 How old are you?   \
# 0                  Male         31-40 years
# 1                Female         21-30 years
# 2                Female         21-30 years
# 3                  Male         21-30 years
# 4                Female         21-30 years
#
#   3 Which city do you shop online from?  \
# 0                                 Delhi
# 1                                 Delhi
# 2                         Greater Noida
# 3                               Karnal
# 4                            Bangalore
#
#    4 What is the Pin Code of where you shop online from?  \
# 0                                             110009
# 1                                             110030
# 2                                             201308
# 3                                             132001
# 4                                             530068
#
#   5 Since How Long You are Shopping Online ?  \
# 0                              Above 4 years
# ...

# %% [markdown]
# ###### Checking Data types

# %%
data.dtypes
# Out:
# 1Gender of respondent                                                   object
# 2 How old are you?                                                      object
# 3 Which city do you shop online from?                                   object
# 4 What is the Pin Code of where you shop online from?                    int64
# 5 Since How Long You are Shopping Online ?                              object
#                                                                          ...
# Longer delivery period                                                  object
# Change in website/Application design                                    object
# Frequent disruption when moving from one page to another                object
# Website is as efficient as before                                       object
# Which of the Indian online retailer would you recommend to a friend?    object
# Length: 71, dtype: object

# %% [markdown]
# ###### Checking Shape of the column

# %%
data.shape
# Out:
# (269, 71)

# %% [markdown]
# ###### Checking null values

# %%
data.isnull().sum()
# Out:
# 1Gender of respondent                                                   0
# 2 How old are you?                                                      0
# 3 Which city do you shop online from?                                   0
# 4 What is the Pin Code of where you shop online from?                   0
# 5 Since How Long You are Shopping Online ?                              0
#                                                                        ..
# Longer delivery period                                                  0
# Change in website/Application design                                    0
# Frequent disruption when moving from one page to another                0
# Website is as efficient as before                                       0
# Which of the Indian online retailer would you recommend to a friend?    0
# Length: 71, dtype: int64

# %%
plt.figure(figsize=[23,9])
sns.heatmap(data.isnull(),cmap='Blues')
plt.show()

# %% [markdown]
# ### Observation-1

# %% [markdown]
# In the above data set
#
#     1. The shape of data set is 269*71 i.e. number of columns is 71 and number of rows is 269.
#
#     2. The columns which are present in the data set, is giving us many informations releted to customer behaviour, Buying pattern of the customer, information releted to various e-commerce platfrom etc.
#
#     3. Data set does not have any null values. Means all the rows and column are filled by data.
#
#     4. All the data are object type. Means there is no numerical data.

# %% [markdown]
# ### Examining the count....

# %% [markdown]
# # 1.

# %%
print(data["1Gender of respondent"].value_counts())
plt.figure(figsize=[8,5])
sns.countplot(data["1Gender of respondent"])
plt.show()
# Out:
# Female    181
# Male       88
# Name: 1Gender of respondent, dtype: int64

# %%
print(data["2 How old are you? "].value_counts())
plt.figure(figsize=[13,5])
sns.countplot(data['2 How old are you? '],palette='icefire')
plt.show()
# Out:
# 31-40 years           81
# 21-30 years           79
# 41-50 yaers           70
# Less than 20 years    20
# 51 years and above    19
# Name: 2 How old are you? , dtype: int64

# %%
print(data['3 Which city do you shop online from?'].value_counts())
plt.figure(figsize=[15,5])
sns.countplot(data['3 Which city do you shop online from?'])
plt.show()
# Out:
# Delhi            58
# Greater Noida    43
# Noida            40
# Bangalore        37
# Karnal           27
# Solan            18
# Ghaziabad        18
# Gurgaon          12
# Merrut            9
# Moradabad         5
# Bulandshahr       2
# Name: 3 Which city do you shop online from?, dtype: int64

# %%
plt.figure(figsize=[10,9])
sns.countplot(y=data['4 What is the Pin Code of where you shop online from?'])
plt.show()

# %%
print(data['5 Since How Long You are Shopping Online ?'].value_counts())
plt.figure(figsize=[15,5])
sns.countplot(data['5 Since How Long You are Shopping Online ?'],palette='Blues')
plt.show()
# Out:
# Above 4 years       98
# 2-3 years           65
# 3-4 years           47
# Less than 1 year    43
# 1-2 years           16
# Name: 5 Since How Long You are Shopping Online ?, dtype: int64

# %%
print(data['6 How many times you have made an online purchase in the past 1 year?'].value_counts())
plt.figure(figsize=[12,7])
sns.countplot(y=data['6 How many times you have made an online purchase in the past 1 year?'],facecolor=(0,0,0,0),edgecolor=sns.color_palette("dark",3))
# Out:
# Less than 10 times    114
# 31-40 times            63
# 41 times and above     47
# 11-20 times            29
# 21-30 times            10
# 42 times and above      6
# Name: 6 How many times you have made an online purchase in the past 1 year?, dtype: int64
# <AxesSubplot:xlabel='count', ylabel='6 How many times you have made an online purchase in the past 1 year?'>

# %%
print(data['8 Which device do you use to access the online shopping?'].value_counts())
plt.figure(figsize=[13,5])
sns.countplot(data['8 Which device do you use to access the online shopping?'],palette='deep')
plt.show()
# Out:
# Smartphone    141
# Laptop         86
# Desktop        30
# Tablet         12
# Name: 8 Which device do you use to access the online shopping?, dtype: int64

# %% [markdown]
# ### Observation-2

# %% [markdown]
# We have some graphical representation of costumer retention data, with the help of this we can easily understand the pattern of customers.
#
#
# ➣ Firstly it is very import for any business to know which type of customers are taking interest towards their product and service, either they are male or female.
# Because of this only company can be able to build there future scheme, will give discount on those product and service which is being loved by particular gender.
#
# Under the customer respondent, the number of females(181) are very high as compare to male(88), it shows that means are not taking interest to give feed back, So company should give some small-small gift coupons to male in order to get the feed back from the males. company will have to attract the male side in order to know men's thinking towards products.
# It will definitely help the company to grow there business.
#
#
#
# ➣ It will make the sense to know about customer age group in order to find healthy customers for the particular product.
#
# As we can see in the graph less then 20 and above 50, means the rate of buying product online is very less when we talk about  teenager and the older people.
#
# The people whom Age is lye between 21 to 50, can be the most preferable customers for making the sales high.
#
#
#
# ➣ In order to sale the product, it will become significant to know about from where customer belongs. It is important because the life of metropolitan city is different from the rural or small city areas, people do not have much time to buy the product from the market.
#
# As per the above result the metropolitan city like Delhi, Greater Noida, Noida and Bangalore gives high customers as compare to other city.
# Bulandshahr, Moradabad, solan and Meerut has few customer and this cities falls in the category of small city.
#
#
#
# ➣ We can measure the customer retention level with the help of "how long shopping is being done by the customers". To measure this, we can divide the time in the scale of year.
#
#
#     Above 4 years       98
#
#     2-3 years           65
#
#     3-4 years           47
#
#     Less than 1 year    43
#
#     1-2 years           16
#
#
# It shows that customer are taking interest( above 4 years : 98 ) towards online shopping. To maintain the customers retention level, company should give more attractive offers, discounts and variety of product.
#
#
#
# ➣ In order to grow any website, It will become more important to know how many times shopping is being done by customer. Above graph is showing how many times customers bought the products online in one year.
#
#     Less than 10 times    114
#
#     31-40 times            63
#
#     41 times and above     47
#
#     11-20 times            29
#
#     21-30 times            10
#
#     42 times and above      6
#
# Around 6-10 people buy products 42 times in a year and most of the people buy products 10 times in a year.
# This will help any website or e-commerce to understand the customer pattern.
#
#
#
#
# ➣ Mostly Online shopping is being done by using mobile phones(141) and then laptop(86).Few people are using tablet(12) and desktop(30).as we can see in the graph.
#
#
#
# ➣ Knowing the pin code number is also one of the crucial part of any website brand. It refers to availability of that particular product in any particular area or location.
# sometimes a specific pin code gives so many customers but company should take care of every pin code location to grape all the customers in order to grow the company monopoly.
#
# Above graph shows that pin code number 201308, 132001, 201310 and 110044 are highest as compare to others, shows availability of all the products is very necessary at particular pin code.

# %% [markdown]
# # 2.

# %%
print(data['18 The content on the website must be easy to read and understand'].value_counts())
plt.figure(figsize=[13,5])
sns.countplot(y=data['18 The content on the website must be easy to read and understand'],palette='BuGn')
plt.show()
# Out:
# Strongly agree (5)       164
# Agree (4)                 80
# Strongly disagree (1)     18
# Indifferent (3)            7
# Name: 18 The content on the website must be easy to read and understand, dtype: int64

# %%
print(data['20 Complete information on listed seller and product being offered is important for purchase decision.'].value_counts())
plt.figure(figsize=[13,8])
sns.countplot(y=data['20 Complete information on listed seller and product being offered is important for purchase decision.'],palette='deep')
plt.show()
# Out:
# Agree (4)                101
# Strongly agree (5)        87
# Indifferent (3)           52
# Dis-agree (2)             18
# Strongly disagree (1)     11
# Name: 20 Complete information on listed seller and product being offered is important for purchase decision., dtype: int64

# %%
print(data['23 Loading and processing speed'].value_counts())
plt.figure(figsize=[10,5])
sns.countplot(data['23 Loading and processing speed'],palette='tab20_r')
plt.show()
# Out:
# Strongly agree (5)       115
# Agree (4)                112
# Dis-agree (2)             18
# Strongly disagree (1)     12
# Indifferent (3)           12
# Name: 23 Loading and processing speed, dtype: int64

# %%
print(data['21 All relevant information on listed products must be stated clearly'].value_counts())
plt.figure(figsize=[13,5])
sns.countplot(x=data['21 All relevant information on listed products must be stated clearly'],palette='ocean')
plt.show()
# Out:
# Agree (4)                132
# Strongly agree (5)       107
# Strongly disagree (1)     18
# Dis-agree (2)             12
# Name: 21 All relevant information on listed products must be stated clearly, dtype: int64

# %%
print(data['25 Convenient Payment methods'].value_counts())
plt.figure(figsize=[13,5])
sns.countplot(data['25 Convenient Payment methods'],palette='deep')
plt.show()
# Out:
# Strongly agree (5)    159
# Agree (4)              80
# Dis-agree (2)          30
# Name: 25 Convenient Payment methods, dtype: int64

# %%
print(data['28 Being able to guarantee the privacy of the customer'].value_counts())
plt.figure(figsize=[13,5])
sns.countplot(data['28 Being able to guarantee the privacy of the customer'],palette='afmhot_r')
plt.show()
# Out:
# Strongly agree (5)    185
# Agree (4)              58
# indifferent (3)        26
# Name: 28 Being able to guarantee the privacy of the customer, dtype: int64

# %%
print(data['33 Return and replacement policy of the e-tailer is important for purchase decision'].value_counts())
plt.figure(figsize=[13,5])
sns.countplot(data['33 Return and replacement policy of the e-tailer is important for purchase decision'],palette='deep')
plt.show()
# Out:
# Strongly agree (5)    198
# Agree (4)              51
# Dis-agree (2)          20
# Name: 33 Return and replacement policy of the e-tailer is important for purchase decision, dtype: int64

# %%
print(data['35 Displaying quality Information on the website improves satisfaction of customers'].value_counts())
plt.figure(figsize=[13,5])
sns.countplot(data['35 Displaying quality Information on the website improves satisfaction of customers'],palette='pink')
plt.show()
# Out:
# Strongly agree (5)    133
# Agree (4)              80
# indifferent (3)        56
# Name: 35 Displaying quality Information on the website improves satisfaction of customers, dtype: int64

# %%
print(data['38 User satisfaction cannot exist without trust'].value_counts())
plt.figure(figsize=[13,5])
sns.countplot(y=data['38 User satisfaction cannot exist without trust'],palette='RdPu')
plt.show()
# Out:
# Strongly agree (5)       122
# Agree (4)                117
# Strongly disagree (1)     18
# Dis-agree (2)              7
# indifferent (3)            5
# Name: 38 User satisfaction cannot exist without trust, dtype: int64

# %%
print(data['40 Provision of complete and relevant product information'].value_counts())
plt.figure(figsize=[13,5])
sns.countplot(data['40 Provision of complete and relevant product information'],palette='gist_yarg_r')
plt.show()
# Out:
# Strongly agree (5)    135
# Agree (4)              98
# indifferent (3)        31
# Disagree (2)            5
# Name: 40 Provision of complete and relevant product information, dtype: int64

# %% [markdown]
# ### Observation-3

# %% [markdown]
# In the observation-3 we will discuss what customer think about the website...
#
# ➣It is required to know about, what customer think about the websites as we can see in the column named "The content on the website must be easy to read and understand".
# Plenty of the customers(246) wants that the content on the website must be easy to read and understand.
#
# Considering this customers can be attracted towards any particular website because it would be easy to read and understand.
#
#
# ➣ When customer go to buy any product, it will become import for most of the customers to check, who is the seller and information related to product. It helps customer to find out many factors, which customer want to know.
#
#
# From the above graph most of the customer think that Complete information on listed seller and product being offered is important for purchase decision.
#
# 101 people are agree with this.
# 87 people are strongly agree with this.
# only 29 people are dis-agree with this.
#
#
# ➣ According to consumer rights, we can ask the seller to provide relevant information related to product and service. It will become more import in e-commerce platform because there is no one to tell about the product, So All relevant information on listed products must be stated clearly.
#
# From the above result :
#
#     Agree                  132
#
#     Strongly agree         107
#
#     Strongly disagree      18
#
#     Dis-agree              12
#
# Most of the people are agree with this statement, In numbers it is around 239.
# Only few people are disagree with this statement, In numbers it is around 30.
#
#
# ➣ Payment is one of the most import step for seller and buyer in order to complete the purchases payment methods should be convenient for customers because it saves the time and provide easy way to give product amount to the seller.
#
# From the above graph all the people around 85% want to get Convenient Payment methods.
#
#     Strongly agree     159
#
#     Agree               80
#
#     Dis-agree           30
#
#
# ➣ It is very necessary for e-commerce to give return and replacement policy to the customers in order to achieve trust and faith.
#
# from the above graph 249 people think that Return and replacement policy of the e-tailer is important for purchase decision.
# only few people think are disagree with this statement.
#
#
# ➣ Quality is the one more import step to concern. We can not touch the product, can not see how actually it looks like. because of this, customer does not satisfy. To improve this website should display the quality information on the website.
#
#
# from the above result e can say that most of the people are agree with this statement.
#
#     Strongly agree (5)    133
#
#     Agree (4)              80
#
#     indifferent (3)        56
#
#
# ➣ Trust from customers plays a major role to grow any website. If customers are unable to trust your product and service then it will become very difficult task to grow. Company need to gain the trust in very first position after that think about profit.
# to adopt this customer would be satisfy and will come to you again and again.
#
# here are the above results:
#
#     Strongly agree (5)       122
#
#     Agree (4)                117
#
#     Strongly disagree (1)     18
#
#     Dis-agree (2)              7
#
#     indifferent (3)            5

# %% [markdown]
# # 3.

# %%
print(data['Wild variety of product on offer'].value_counts())
plt.figure(figsize=[22,7])
sns.countplot(data['Wild variety of product on offer'],palette='deep')
plt.show()
# Out:
# Amazon.in, Flipkart.com                              130
# Amazon.in                                             43
# Amazon.in, Myntra.com                                 20
# Flipkart.com, Myntra.com                              15
# Myntra.com                                            15
# Amazon.in, Flipkart.com, Myntra.com, Snapdeal.com     14
# Amazon.in, Flipkart.com, Paytm.com                    13
# Flipkart.com                                          12
# Paytm.com                                              7
# Name: Wild variety of product on offer, dtype: int64

# %%
print(data['Fast loading website speed of website and application'].value_counts())
plt.figure(figsize=[13,5])
sns.countplot(y=data['Fast loading website speed of website and application'],palette='deep')
plt.show()
# Out:
# Amazon.in                                                       51
# Amazon.in, Paytm.com                                            44
# Amazon.in, Flipkart.com, Myntra.com                             30
# Amazon.in, Flipkart.com, Paytm.com, Myntra.com, Snapdeal.com    30
# Amazon.in, Flipkart.com                                         30
# Amazon.in, Flipkart.com, Snapdeal.com                           25
# Amazon.in, Flipkart.com, Paytm.com                              25
# Amazon.in, Flipkart.com, Myntra.com, Snapdeal.com               14
# Snapdeal.com                                                    12
# Flipkart.com                                                     8
# Name: Fast loading website speed of website and application, dtype: int64

# %%
print(data['Quickness to complete purchase'].value_counts())
plt.figure(figsize=[19,8])
sns.countplot(data['Quickness to complete purchase'],palette='PiYG')
plt.show()
# Out:
# Amazon.com                                                   66
# Amazon.com, Flipkart.com, Paytm.com                          47
# Amazon.com, Flipkart.com                                     37
# Amazon.com, Flipkart.com, Myntra.com                         30
# Paytm.com                                                    25
# Amazon.com, Paytm.com, Myntra.com                            20
# Amazon.com, Flipkart.com, Paytm.com, Myntra.com, Snapdeal    15
# Flipkart.com                                                 15
# Flipkart.com, Myntra.com, Snapdeal                           14
# Name: Quickness to complete purchase, dtype: int64

# %%
print(data['Privacy of customers’ information'].value_counts())
plt.figure(figsize=[18,10])
sns.countplot(y=data['Privacy of customers’ information'],facecolor=(0,0,0,0),edgecolor=sns.color_palette("dark",3))
plt.show()
# Out:
# Amazon.in                                                       71
# Amazon.in, Flipkart.com                                         54
# Amazon.in, Flipkart.com, Myntra.com                             25
# Amazon.in, Flipkart.com, Paytm.com, Myntra.com, Snapdeal.com    24
# Paytm.com                                                       18
# Myntra.com                                                      15
# Amazon.in, Paytm.com                                            15
# Flipkart.com                                                    15
# Amazon.in, Flipkart.com, Myntra.com, Snapdeal.com               14
# Amazon.in, Flipkart.com, Paytm.com                              11
# Amazon.in, Flipkart.com, Snapdeal.com                            7
# Name: Privacy of customers’ information, dtype: int64

# %%
print(data['Speedy order delivery '].value_counts())
plt.figure(figsize=[22,9])
sns.countplot(data['Speedy order delivery '],palette='mako')
plt.show()
# Out:
# Amazon.in                                 107
# Amazon.in, Flipkart.com                    82
# Amazon.in, Flipkart.com, Snapdeal.com      36
# Amazon.in, Flipkart.com, Myntra.com        15
# Flipkart.com                               15
# Flipkart.com, Myntra.com, Snapdeal.com     14
# Name: Speedy order delivery , dtype: int64

# %%
print(data['Longer time to get logged in (promotion, sales period)'].value_counts())
plt.figure(figsize=[22,9])
sns.countplot(data['Longer time to get logged in (promotion, sales period)'],palette='deep')
plt.show()
# Out:
# Amazon.in                                57
# Amazon.in, Flipkart.com                  38
# Paytm.com                                38
# Myntra.com                               35
# Amazon.in, Flipkart.com, Snapdeal.com    29
# Snapdeal.com                             25
# Flipkart.com, Paytm.com                  15
# Flipkart.com, Paytm.com, Snapdeal.com    13
# Amazon.in, Paytm.com                     11
# Flipkart.com                              8
# Name: Longer time to get logged in (promotion, sales period), dtype: int64

# %%
print(data['Longer time in displaying graphics and photos (promotion, sales period)'].value_counts())
plt.figure(figsize=[13,5])
sns.countplot(y=data['Longer time in displaying graphics and photos (promotion, sales period)'],palette='Set1')
plt.show()
# Out:
# Amazon.in, Flipkart.com                60
# Amazon.in                              39
# Myntra.com                             35
# Snapdeal.com                           34
# Myntra.com, Snapdeal.com               25
# Flipkart.com, Snapdeal.com             19
# Paytm.com                              15
# Flipkart.com                           15
# Amazon.in, Myntra.com, Snapdeal.com    14
# Amazon.in, Paytm.com                   13
# Name: Longer time in displaying graphics and photos (promotion, sales period), dtype: int64

# %%
print(data['Longer page loading time (promotion, sales period)'].value_counts())
plt.figure(figsize=[23,10])
sns.countplot(data['Longer page loading time (promotion, sales period)'],palette='afmhot_r')
plt.show()
# Out:
# Myntra.com                          61
# Paytm.com                           59
# Flipkart.com                        32
# Snapdeal.com                        23
# Amazon.in, Flipkart.com             18
# Amazon.in                           16
# Paytm.com, Snapdeal.com             15
# Amazon.in, Snapdeal.com             14
# Amazon.in, Paytm.com                13
# Flipkart.com, Snapdeal.com          11
# Amazon.in, Paytm.com, Myntra.com     7
# Name: Longer page loading time (promotion, sales period), dtype: int64

# %%
print(data['Limited mode of payment on most products (promotion, sales period)'].value_counts())
plt.figure(figsize=[13,5])
sns.countplot(y=data['Limited mode of payment on most products (promotion, sales period)'],palette='pink_r')
plt.show()
# Out:
# Snapdeal.com                87
# Amazon.in                   62
# Flipkart.com                31
# Amazon.in, Flipkart.com     29
# Paytm.com                   25
# Paytm.com, Snapdeal.com     15
# Amazon.in, Paytm.com        13
# Myntra.com, Snapdeal.com     7
# Name: Limited mode of payment on most products (promotion, sales period), dtype: int64

# %%
print(data['Longer delivery period'].value_counts())
plt.figure(figsize=[13,5])
sns.countplot(data['Longer delivery period'],palette='deep')
plt.show()
# Out:
# Paytm.com                  72
# Snapdeal.com               64
# Flipkart.com               44
# Amazon.in                  37
# Paytm.com, Snapdeal.com    26
# Myntra.com                 26
# Name: Longer delivery period, dtype: int64

# %%
print(data['Change in website/Application design'].value_counts())
plt.figure(figsize=[13,5])
sns.countplot(data['Change in website/Application design'],palette='Accent')
plt.show()
# Out:
# Amazon.in                   96
# Paytm.com                   63
# Amazon.in, Flipkart.com     45
# Myntra.com                  30
# Flipkart.com                20
# Snapdeal.com                 8
# Flipkart.com, Myntra.com     7
# Name: Change in website/Application design, dtype: int64

# %%
print(data['Which of the Indian online retailer would you recommend to a friend?'].value_counts())
plt.figure(figsize=[13,5])
sns.countplot(y=data['Which of the Indian online retailer would you recommend to a friend?'],palette='gist_heat')
plt.show()
# Out:
# Amazon.in                                            79
# Amazon.in, Flipkart.com                              62
# Flipkart.com                                         39
# Amazon.in, Myntra.com                                30
# Amazon.in, Paytm.com, Myntra.com                     20
# Amazon.in, Flipkart.com, Myntra.com                  15
# Amazon.in, Paytm.com                                 13
# Flipkart.com, Paytm.com, Myntra.com, snapdeal.com    11
# Name: Which of the Indian online retailer would you recommend to a friend?, dtype: int64

# %% [markdown]
# ### Observation-4

# %% [markdown]
# We observed the comparison between various e-commerce platform.
#
#
# ➣ The fast loading speed of website attracts the customer towards their web page. If customers find a webpage slow then they can switch the platform for easy access of their shopping.
#
# According to the customers(51) only Amazon.in provides a fast loading website and around 44 people chose Amazon and Paytm as the fast loading web page speed.
#
# Some people(around 30) chose Amazon.in, Flipkart.com and Myntra.com as the fast loading web page speed.
#
#
# ➣ Some customers wants 'Quickness to complete purchase' in order to do shopping. Some web page take a lot of time to complete porches it give negative impact on the customers mind.
#
#
# a. Most of the people chose Amazon.com as a quick complete purchase platform, around 66 people vote
#
# b. There are some people also who chose Amazon.com, Flipkart.com and Paytm.com as a quick complete purchase platform, 47 people vote.
#
# as we can see in below table:
#
#
#     Amazon.com                                                   66
#
#     Amazon.com, Flipkart.com, Paytm.com                          47
#
#     Amazon.com, Flipkart.com                                     37
#
#     Amazon.com, Flipkart.com, Myntra.com                         30
#
#     Paytm.com                                                    25
#
#     Amazon.com, Paytm.com, Myntra.com                            20
#
#     Amazon.com, Flipkart.com, Paytm.com, Myntra.com, Snapdeal    15
#
#     Flipkart.com                                                 15
#
#     Flipkart.com, Myntra.com, Snapdeal                           14
#
#
# ➣ Privacy is one of the most important thing for any customer. Sometimes people do not like to share their private things like likeness, Dis likeness, what Thay are finding on website. So company should take care of customer privacy.
#
# Above data shows amazon, flipkart and myntra take care of customer privacy that why most of the people chose these platform.
#
#
#     Amazon.in                                                       71
#
#     Amazon.in, Flipkart.com                                         54
#
#     Amazon.in, Flipkart.com, Myntra.com                             25
#
#     Amazon.in, Flipkart.com, Paytm.com, Myntra.com, Snapdeal.com    24
#
#     Paytm.com                                                       18
#
#     Myntra.com                                                      15
#
#     Amazon.in, Paytm.com                                            15
#
#     Flipkart.com                                                    15
#
#     Amazon.in, Flipkart.com, Myntra.com, Snapdeal.com               14
#
#     Amazon.in, Flipkart.com, Paytm.com                              11
#
#     Amazon.in, Flipkart.com, Snapdeal.com                            7
#
#
# ➣ Speedy order delivery refers to getting more customers from another platform to our own platform. Because of this
#
# a) Customers attracts towards us.
#
# b) Help to retain the customer.
#
# c) It helps to gain the Trust and satisfaction.
#
# As we can see in the table Amazon(107) and flip kart(82) archived highest point.
#
#
#     Amazon.in                                 107
#
#     Amazon.in, Flipkart.com                    82
#
#     Amazon.in, Flipkart.com, Snapdeal.com      36
#
#     Amazon.in, Flipkart.com, Myntra.com        15
#
#     Flipkart.com                               15
#
#     Flipkart.com, Myntra.com, Snapdeal.com     14
#
#
# ➣ In order to retain the customers website should give the better  and quick response. Because of this customer feels batter experience and saved their time as well.
#
# we have some data in which customer gives the ranking to different different websites.
#
# a) According to customers myntra and paytm takes a much more time to loading the page.
#
# b) Amazon and flipkart take fewer time according to the data.
#
#
#
# ➣ In the market different types of customers are present and every other customer have different type of tendency to pay the amount to the website. So it become crucial thing to provide various type of payment methods. If customer do not have a tendency to pay using credit card or phone pay etc. then website should provide cash on delivery to the customer in order to retain them.
#
# According to people
#
# a) Snapdeal provide limited payment mode.
#
# b) Amazon also provides limited payment mode.
#
# c) Flipkart holds 3rd position for the same .
#
# (ACCORDING TO CUSTOMERS REVIEW)
#
#
#     Snapdeal.com                87
#
#     Amazon.in                   62
#
#     Flipkart.com                31
#
#     Amazon.in, Flipkart.com     29
#
#     Paytm.com                   25
#
#     Paytm.com, Snapdeal.com     15
#
#     Amazon.in, Paytm.com        13
#
#     Myntra.com, Snapdeal.com     7
#
#
# ➣ Because of Longer delivery period, customer can switch the platform to another platform. It means company should be focus on fastest delivery of the product.
#
# a) According to the customer Paytm and Snapdeal takes too much time to deliver the product.
#
# b) Flipkart and amazon also takes time but less people wrote about amazon and flip kart.
#
#
#     Paytm.com                     72
#
#     Snapdeal.com                  64
#
#     Flipkart.com                  44
#
#     Amazon.in                     37
#
#     Paytm.com, Snapdeal.com       26
#
#     Myntra.com                    26
#
#
# ➣ Finally it is like a report card of any website when customer recommend any particular website to others. And this recommendation becomes a success of website.
#
# a) According to the customers Amazon is the best online retailer which will be recommend by the them.(79 people vote).
#
# b) In the second recommendation flip kart achieved highest votes.
#
# c) Myntra got number third.

# %% [markdown]
# .

# %% [markdown]
# ### Relations between the groups

# %% [markdown]
# ###### Observation-5

# %%
plt.figure(figsize=(15,8))
sns.countplot(data['1Gender of respondent'],hue=data['Which of the Indian online retailer would you recommend to a friend?'])
plt.show()

# %% [markdown]
# As we can see in the above graph
#
#     Most of the male is recommending the amazon website with friends and then flipkart where as myntra, Snapdeal is recommendtion is very less.
#
#     If we see in the female column here also highest recommending website is Amazon and then flipkart.
#
#     We can say that Amazon is highly recommending website by both the genders.

# %% [markdown]
# ###### Observation-6

# %%
plt.figure(figsize=[25,12])
sns.countplot(data['3 Which city do you shop online from?'],hue=data['2 How old are you? '])
plt.show()

# %% [markdown]
# As we can see in the above graph
#
#     Mostly young peoples whos age is 31 to 50 are buying products from website.
#
#     From kernal less then 20 and above 50 people do less shoping from websites.
#
#     From banglore shopping is being done by 21-30 age group.
#
#     From bulandshahr only 31-40 age group is active to buy products online.
#
#     We can canclude that age group is changing with the change in city.

# %% [markdown]
# ###### Observation-7

# %%
plt.figure(figsize=[20,10])
sns.countplot(data['5 Since How Long You are Shopping Online ?'],hue=data['1Gender of respondent'],palette='BuGn')
plt.show()

# %% [markdown]
# From the above graph we can conclude that...
#
#     In all the duration of time above 4 years to 1-2 years, The population of females in shopping is very high as compare to males.

# %% [markdown]
# ###### Observation-8

# %%
plt.figure(figsize=(20,7))
sns.set(style='whitegrid')
ww=sns.stripplot(x='Longer delivery period',y='3 Which city do you shop online from?',data=data)
plt.show()

# %% [markdown]
# This above graph represent the how long time is taken by each specific website in particular city.
#
#     Paytm and Snapdeal takes longer time to deliver their products in gurgaon, ghaziabad, bulandshahr and muradabad and provide fastest delivery in delhi, noida, bangalore and karnal as well.
#
#     Amazon takes long time to deliver their product in karnal, merrut , moradabad and bulandshahr but provides fast delivery in delhi, noida, karnal and solan.
#
#     Myntra takes long time to deliver their product in  moradabad, bulandshahr,ghaziabad, karnal and solan.
#
#     Flipkart provides fastest delivery in most of the city as compare to others as shown in the graph.

# %% [markdown]
# ###### Observation-9

# %%
plt.figure(figsize=[20,7])
sns.countplot(data['8 Which device do you use to access the online shopping?'],hue=data['1Gender of respondent'],palette='pink')
plt.show()

# %% [markdown]
# From the above graph we can say that:
#
#     Desktop users are equal
#
#     Female is higher in numbers to do online shopping from smartphones.
#
#     From tablet, only males do online shopping
#
#     From laptop, females do  more online shopping than males.

# %% [markdown]
# --------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# #### In order to retain the customers, company must follow all the above observations and by following this, company can make permanent customers and also can grow in future.
# #### Company should see each and every aspect of customers behaviour in order to provide best services and products.
